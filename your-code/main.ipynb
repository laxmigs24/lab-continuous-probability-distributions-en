# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here
from scipy.stats import uniform

# %%
def generate_uniform_scipy(bottom, ceiling, count):
    return uniform.rvs(loc=bottom, scale=ceiling-bottom, size=count)

# %%
# Set 1: bottom=10, ceiling=15, count=100
set_1 = generate_uniform(10, 15, 100)

# Set 2: (Example if you need a different set, e.g., 0 to 1 with 1000 samples)
set_2 = generate_uniform(0, 1, 1000)

# Preview the first few numbers of set_1
print(set_1[:10])
# Out:
# [14.4678596  10.81202894 12.00104645 14.02474728 11.52248585 11.09697641
#  11.05677001 11.54408689 13.45705972 10.96841276]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
# Plotting Set 1 (10 to 15, 100 samples)
plt.hist(set_1, bins=10, color='red', edgecolor='black')
plt.title('Uniform Distribution (10-15, n=100)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %%
# your code here
# Plotting Set 2 (0 to 1, 1000 samples)
plt.hist(set_2, bins=10, color='purple', edgecolor='black')
plt.title('Uniform Distribution (0-1, n=1000)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
def generate_normal(mu, s, count):
    return np.random.normal(mu, s, count)

# %%
# your code here
dist_1 = generate_normal(10, 1, 1000)

# 3. Generate 1,000 normally distributed numbers (Avg=10, Std=50)
dist_2 = generate_normal(10, 50, 1000)

# 4. Plot the distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.hist(dist_1, bins=50, color='red', edgecolor='black')
ax1.set_title('Average = 10, Std = 1')
ax1.set_xlabel('Value')
ax1.set_ylabel('Frequency')


ax2.hist(dist_2, bins=50, color='purple', edgecolor='black')
ax2.set_title('Average = 10, Std = 50')
ax2.set_xlabel('Value')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
import pandas as pd
import matplotlib.pyplot as plt # viz
import seaborn as sns # better viz
import numpy as np # numerical python

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
df = pd.read_csv("/Users/laxmigupte/Desktop/Ironhack/week4/D2/lab-continuous-probability-distributions-en/your-code/vehicles.csv")

# %%
# your code here
plt.hist(df['Fuel Barrels/Year'], bins=10, color='red', edgecolor='black')
plt.title('Fuel Barrels/year')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.hist(df['CO2 Emission Grams/Mile'], bins=10, color='purple', edgecolor='black')
plt.title('Fuel Barrels/year')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.hist(df['Combined MPG'], bins=10, color='blue', edgecolor='black')
plt.title('Fuel Barrels/year')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
# 1. Create a function that returns exponentially distributed numbers
def generate_exponential(mean_val, size_val):
    # numpy.random.exponential uses 'scale', which is equal to the mean
    return np.random.exponential(scale=mean_val, size=size_val)

# 2. Generate two number sequences with sizes 10 and 100 (mean = 10)
seq_10 = generate_exponential(10, 10)
seq_100 = generate_exponential(10, 100)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
# Plot for size 10
ax1.hist(seq_10, bins=100, color='red', edgecolor='black')
ax1.set_title('Exponential Distribution (Size=10)')
ax1.set_xlabel('Value')
ax1.set_ylabel('Frequency')

# Plot for size 100
ax2.hist(seq_100, bins=100, color='purple', edgecolor='black')
ax2.set_title('Exponential Distribution (Size=100)')
ax2.set_xlabel('Value')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# %%
mean = 10
lambda_val = 1/10
threshold =15

# %%
prob_scipy = expon.cdf(x=threshold, scale=mean)
print(f"Probability : {prob_scipy:.4f}")
# Out:
# Probability : 0.7769

# %%
# your answer here
# Hint: This is same as saying P(x<15)

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %% [markdown]
# The probability that the customer will spend more than 15 minutes is 77.69%
